# %% [markdown]
# <a href="https://colab.research.google.com/github/raichalvarghese/Data_Science_Lab/blob/master/simple_web_crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/CNN')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/CNN_(disambiguation)
# /wiki/CNN_Center
# /wiki/Atlanta
# /wiki/1080i
# /wiki/High-definition_television
# /wiki/Letterboxing_(filming)
# /wiki/480i
# /wiki/Standard-definition_television
# /wiki/Turner_Broadcasting_System
# /wiki/Time_Warner
# /wiki/AOL_Time_Warner
# /wiki/AT%26T
# /wiki/Warner_Bros._Discovery
# /wiki/Chris_Licht
# /wiki/Vice_President
# /wiki/Chief_Financial_Officer
# /wiki/Amy_Entelis
# /wiki/Vice_President
# /wiki/Ken_Jautz
# /wiki/HLN_(TV_network)
# /wiki/Andrew_Morse
# /wiki/CNN_Airport
# /wiki/CNN_Arabic
# /wiki/CNN_Brazil
# /wiki/CNN_Chile
# /wiki/CNN_en_Espa%C3%B1ol
# /wiki/CNN_Indonesia
# /wiki/CNN_International
# /wiki/CNN-News18
# /wiki/CNN_Philippines
# /wiki/CNN_Portugal
# /wiki/CNN_T%C3%BCrk
# /wiki/HLN_(TV_network)
# /wiki/Antena_3_CNN
# /wiki/Adult_Swim
# /wiki/Boomerang_(TV_network)
# /wiki/Cartoon_Network
# /wiki/Cartoonito_(American_programming_block)
# /wiki/Discovery_Family
# /wiki/Toonami
# /wiki/Animal_Planet
# /wiki/Cinemax
# ...
